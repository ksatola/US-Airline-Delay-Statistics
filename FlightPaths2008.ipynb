# %% [markdown]
# This notebook builds an dataset (from 2 sub-datasets) used for path-based view mainly used for cancelled flights used in Tableau presentation

# %%
import pandas as pd

# %%
#df1 = pd.read_csv('data/2008.csv', nrows=10000, encoding='latin-1')
df1 = pd.read_csv('data/2008.csv', nrows=None, encoding='latin-1')

# %%
df1.head(8).T
# Out:
#                         0       1       2       3       4       5       6  \
# Year                 2008    2008    2008    2008    2008    2008    2008
# Month                   1       1       1       1       1       1       1
# DayofMonth              3       3       3       3       3       3       3
# DayOfWeek               4       4       4       4       4       4       4
# DepTime              2003     754     628     926    1829    1940    1937
# CRSDepTime           1955     735     620     930    1755    1915    1830
# ArrTime              2211    1002     804    1054    1959    2121    2037
# CRSArrTime           2225    1000     750    1100    1925    2110    1940
# UniqueCarrier          WN      WN      WN      WN      WN      WN      WN
# FlightNum             335    3231     448    1746    3920     378     509
# TailNum            N712SW  N772SW  N428WN  N612SW  N464WN  N726SW  N763SW
# ActualElapsedTime     128     128      96      88      90     101     240
# CRSElapsedTime        150     145      90      90      90     115     250
# AirTime               116     113      76      78      77      87     230
# ArrDelay              -14       2      14      -6      34      11      57
# DepDelay                8      19       8      -4      34      25      67
# Origin                IAD     IAD     IND     IND     IND     IND     IND
# Dest                  TPA     TPA     BWI     BWI     BWI     JAX     LAS
# Distance              810     810     515     515     515     688    1591
# TaxiIn                  4       5       3       3       3       4       3
# TaxiOut                 8      10      17       7      10      10       7
# Cancelled               0       0       0       0       0       0       0
# CancellationCode      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Diverted                0       0       0       0       0       0       0
# CarrierDelay          NaN     NaN     NaN     NaN       2     NaN      10
# WeatherDelay          NaN     NaN     NaN     NaN       0     NaN       0
# NASDelay              NaN     NaN     NaN     NaN       0     NaN       0
# SecurityDelay         NaN     NaN     NaN     NaN       0     NaN       0
# LateAircraftDelay     NaN     NaN     NaN     NaN      32     NaN      47
#
#                         7
# Year                 2008
# Month                   1
# DayofMonth              3
# DayOfWeek               4
# DepTime              1039
# CRSDepTime           1040
# ArrTime              1132
# CRSArrTime           1150
# UniqueCarrier          WN
# FlightNum             535
# TailNum            N428WN
# ActualElapsedTime     233
# CRSElapsedTime        250
# AirTime               219
# ArrDelay              -18
# DepDelay               -1
# Origin                IND
# Dest                  LAS
# Distance             1591
# TaxiIn                  7
# TaxiOut                 7
# Cancelled               0
# CancellationCode      NaN
# Diverted                0
# CarrierDelay          NaN
# WeatherDelay          NaN
# NASDelay              NaN
# SecurityDelay         NaN
# LateAircraftDelay     NaN

# %%
#dfclean = old[['A', 'C', 'D']].copy()

# %%
df2 = pd.read_csv('data/airports.csv', nrows=None, encoding='latin-1')

# %%
df2.head(8).T
# Out:
#                    0                     1                 2             3  \
# iata             00M                   00R               00V           01G
# airport     Thigpen   Livingston Municipal       Meadow Lake  Perry-Warsaw
# city     Bay Springs            Livingston  Colorado Springs         Perry
# state             MS                    TX                CO            NY
# country          USA                   USA               USA           USA
# lat          31.9538               30.6859           38.9457       42.7413
# long        -89.2345              -95.0179           -104.57      -78.0521
#
#                         4                  5            6           7
# iata                  01J                01M          02A         02C
# airport  Hilliard Airpark  Tishomingo County  Gragg-Wade      Capitol
# city             Hilliard            Belmont      Clanton  Brookfield
# state                  FL                 MS           AL          WI
# country               USA                USA          USA         USA
# lat                30.688            34.4917      32.8505     43.0875
# long             -81.9059           -88.2011     -86.6115    -88.1779

# %%
# Unify column name convention
df2.columns = ['Iata', 'Airport', 'City', 'State', 'Country', 'Latitude', 'Longitude']

# %%
df2.head(8).T
# Out:
#                      0                     1                 2             3  \
# Iata               00M                   00R               00V           01G
# Airport       Thigpen   Livingston Municipal       Meadow Lake  Perry-Warsaw
# City       Bay Springs            Livingston  Colorado Springs         Perry
# State               MS                    TX                CO            NY
# Country            USA                   USA               USA           USA
# Latitude       31.9538               30.6859           38.9457       42.7413
# Longitude     -89.2345              -95.0179           -104.57      -78.0521
#
#                           4                  5            6           7
# Iata                    01J                01M          02A         02C
# Airport    Hilliard Airpark  Tishomingo County  Gragg-Wade      Capitol
# City               Hilliard            Belmont      Clanton  Brookfield
# State                    FL                 MS           AL          WI
# Country                 USA                USA          USA         USA
# Latitude             30.688            34.4917      32.8505     43.0875
# Longitude          -81.9059           -88.2011     -86.6115    -88.1779

# %%
# Build FlightPaths view for map visualization in Tableau (2 datapoints per each path: From-To)
path_id = 0
items = []

# For each row
for index, row in df1.iterrows():
    #print("Original: ", row['Origin'], row['Dest'])
    path_id = path_id + 1
    delayed = 0
    if row['ArrDelay'] > 15: delayed = 1
    
    items.append({
        'PathId': path_id,
        'PointOrder': 1,
        'Iata': row['Origin'],
        'Cancelled': row['Cancelled'],
        'Delayed': delayed,
        'From': row['Origin'],
        'To': row['Dest']
    })
    
    items.append({
        'PathId': path_id,
        'PointOrder': 2,
        'Iata': row['Dest'],
        'Cancelled': row['Cancelled'],
        'Delayed': delayed,
        'From': row['Origin'],
        'To': row['Dest']
    })
    
#df['Path_Id'] = index
df = pd.DataFrame(items, columns = ['PathId', 'PointOrder', 'Iata', 'Cancelled', 'Delayed', 'From', 'To'])
df.head(10)
# Out:
#    PathId  PointOrder Iata  Cancelled  Delayed From   To
# 0       1           1  IAD          0        0  IAD  TPA
# 1       1           2  TPA          0        0  IAD  TPA
# 2       2           1  IAD          0        0  IAD  TPA
# 3       2           2  TPA          0        0  IAD  TPA
# 4       3           1  IND          0        0  IND  BWI
# 5       3           2  BWI          0        0  IND  BWI
# 6       4           1  IND          0        0  IND  BWI
# 7       4           2  BWI          0        0  IND  BWI
# 8       5           1  IND          0        1  IND  BWI
# 9       5           2  BWI          0        1  IND  BWI

# %%
# Inner join df and df2 on Iata
#df_out = pd.merge(left=df, right=df2, how='inner', on='Iata').sort_values('PathId')
df_out = pd.merge(left=df, right=df2, how='inner', on='Iata')
df_out.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14019456 entries, 0 to 14019455
# Data columns (total 13 columns):
# PathId        14019456 non-null int64
# PointOrder    14019456 non-null int64
# Iata          14019456 non-null object
# Cancelled     14019456 non-null int64
# Delayed       14019456 non-null int64
# From          14019456 non-null object
# To            14019456 non-null object
# Airport       14019456 non-null object
# City          14009907 non-null object
# State         14009907 non-null object
# Country       14019456 non-null object
# Latitude      14019456 non-null float64
# Longitude     14019456 non-null float64
# dtypes: float64(2), int64(4), object(7)
# memory usage: 1.5+ GB

# %%
# Add PathName
df_out['PathName'] = df_out['From'] + '->' + df_out['To']

# %%
df_out.sort_values('PathId').head(10)
# Out:
#         PathId  PointOrder Iata  Cancelled  Delayed From   To  \
# 0            1           1  IAD          0        0  IAD  TPA
# 152053       1           2  TPA          0        0  IAD  TPA
# 1            2           1  IAD          0        0  IAD  TPA
# 152054       2           2  TPA          0        0  IAD  TPA
# 393885       3           2  BWI          0        0  IND  BWI
# 308403       3           1  IND          0        0  IND  BWI
# 393886       4           2  BWI          0        0  IND  BWI
# 308404       4           1  IND          0        0  IND  BWI
# 393887       5           2  BWI          0        1  IND  BWI
# 308405       5           1  IND          0        1  IND  BWI
#
#                                    Airport          City State Country  \
# 0          Washington Dulles International     Chantilly    VA     USA
# 152053                Tampa International          Tampa    FL     USA
# 1          Washington Dulles International     Chantilly    VA     USA
# 152054                Tampa International          Tampa    FL     USA
# 393885  Baltimore-Washington International     Baltimore    MD     USA
# 308403          Indianapolis International  Indianapolis    IN     USA
# 393886  Baltimore-Washington International     Baltimore    MD     USA
# 308404          Indianapolis International  Indianapolis    IN     USA
# 393887  Baltimore-Washington International     Baltimore    MD     USA
# 308405          Indianapolis International  Indianapolis    IN     USA
#
#          Latitude  Longitude  PathName
# 0       38.944532 -77.455810  IAD->TPA
# 152053  27.975472 -82.533250  IAD->TPA
# 1       38.944532 -77.455810  IAD->TPA
# 152054  27.975472 -82.533250  IAD->TPA
# 393885  39.175402 -76.668198  IND->BWI
# 308403  39.717329 -86.294384  IND->BWI
# 393886  39.175402 -76.668198  IND->BWI
# 308404  39.717329 -86.294384  IND->BWI
# 393887  39.175402 -76.668198  IND->BWI
# 308405  39.717329 -86.294384  IND->BWI

# %%
df_out.to_csv('data/FlighPaths2008.csv', index=False)

# %%
# Used later to aggregate flight connections
df_out['Total'] = 1 # to summarize total flight for one direction
df_out['Problematic'] = 0 # to count problematic flights

# %%
# Populate Problematic with 1 if Cancelled or Delayed
df_out.loc[(df_out['Cancelled'] == 1) | (df_out['Delayed'] == 1), ['Problematic']] = 1

# %%
#df_out[df_out["Iata"] == 'IAD' and df_out['PointOrder'] == 1]

mask = ((df_out.Iata == 'IAD') & (df_out.Delayed == 1))
df_out2 = df_out[mask]
df_out2
# Out:
#          PathId  PointOrder Iata  Cancelled  Delayed From   To  \
# 2           135           2  IAD          0        1  LAS  IAD
# 3           603           2  IAD          0        1  MCO  IAD
# 4           604           2  IAD          0        1  MCO  IAD
# 5           741           2  IAD          0        1  MDW  IAD
# 7           743           2  IAD          0        1  MDW  IAD
# 9           745           2  IAD          0        1  MDW  IAD
# 10          746           2  IAD          0        1  MDW  IAD
# 11         2281           2  IAD          0        1  TPA  IAD
# 12         2282           2  IAD          0        1  TPA  IAD
# 19         3435           1  IAD          0        1  IAD  MDW
# 27         4179           2  IAD          0        1  MDW  IAD
# 29         4181           2  IAD          0        1  MDW  IAD
# 45         6792           2  IAD          0        1  LAS  IAD
# 51         7311           2  IAD          0        1  MDW  IAD
# 57         9603           1  IAD          0        1  IAD  MDW
# 58         9604           1  IAD          0        1  IAD  MDW
# 60         9606           1  IAD          0        1  IAD  MDW
# 67        10313           2  IAD          0        1  MDW  IAD
# 72        10318           2  IAD          0        1  MDW  IAD
# 73        11765           2  IAD          0        1  TPA  IAD
# 80        12909           1  IAD          0        1  IAD  MDW
# 86        13047           2  IAD          0        1  LAS  IAD
# 89        13653           2  IAD          0        1  MDW  IAD
# 93        13657           2  IAD          0        1  MDW  IAD
# 95        15193           2  IAD          0        1  TPA  IAD
# 102       16345           1  IAD          0        1  IAD  MDW
# 117       18629           2  IAD          0        1  TPA  IAD
# 152022  -77.45581  ATL->IAD      1            1
# 152023  -77.45581  IAD->ATL      1            1
# 152025  -77.45581  ATL->IAD      1            1
# 152027  -77.45581  ATL->IAD      1            1
# 152029  -77.45581  ATL->IAD      1            1
# 152031  -77.45581  IAD->ATL      1            1
# 152032  -77.45581  ATL->IAD      1            1
# 152038  -77.45581  SLC->IAD      1            1
# 152041  -77.45581  ATL->IAD      1            1
# 152043  -77.45581  IAD->ATL      1            1
# 152046  -77.45581  IAD->SLC      1            1
#
# [36426 rows x 16 columns]

# %%
df_summary = df_out.groupby(['PathName']).size()
df_summary

df3 = pd.DataFrame({'FlightsCount' : df_summary}).reset_index()

# %%
df3.head(10)
# Out:
#    PathName  FlightsCount
# 0  ABE->ATL          1706
# 1  ABE->BHM             2
# 2  ABE->CLE          1610
# 3  ABE->CLT           930
# 4  ABE->CVG           494
# 5  ABE->DTW          1994
# 6  ABE->JFK             6
# 7  ABE->LGA            18
# 8  ABE->ORD          2850
# 9  ABE->PHL             4

# %%
# Merge df_arch_clean and df_api_clean into df_arch_clean
#df_arch_clean = pd.merge(left=df_arch_clean, right=df_api_clean, how='left', on='tweet_id')

# %%
df_summary2 = df_out.groupby(['PathName'])[['Delayed']].sum()
df_summary2.head(10)
# Out:
#           Delayed
# PathName
# ABE->ATL      366
# ABE->BHM        0
# ABE->CLE      174
# ABE->CLT      106
# ABE->CVG       32
# ABE->DTW      304
# ABE->JFK        6
# ABE->LGA       16
# ABE->ORD      728
# ABE->PHL        2

# %%
df_summary3 = df_out.groupby(['PathName'])[['Cancelled']].sum()
df_summary3.head(10)
# Out:
#           Cancelled
# PathName
# ABE->ATL         28
# ABE->BHM          0
# ABE->CLE         26
# ABE->CLT         14
# ABE->CVG          6
# ABE->DTW         52
# ABE->JFK          0
# ABE->LGA          0
# ABE->ORD        178
# ABE->PHL          0

# %%
df_summary4 = df_out.groupby(['PathName']).agg({
    'Total': 'count',
    'Delayed': sum,
    'Cancelled': sum,
    'Problematic': sum})
# Add index as another column
df_summary4['PathName'] = df_summary4.index
df_summary4.head(10)
# Out:
#           Total  Delayed  Cancelled  Problematic  PathName
# PathName
# ABE->ATL   1706      366         28          394  ABE->ATL
# ABE->BHM      2        0          0            0  ABE->BHM
# ABE->CLE   1610      174         26          200  ABE->CLE
# ABE->CLT    930      106         14          120  ABE->CLT
# ABE->CVG    494       32          6           38  ABE->CVG
# ABE->DTW   1994      304         52          356  ABE->DTW
# ABE->JFK      6        6          0            6  ABE->JFK
# ABE->LGA     18       16          0           16  ABE->LGA
# ABE->ORD   2850      728        178          906  ABE->ORD
# ABE->PHL      4        2          0            2  ABE->PHL

# %%
#df_out = pd.merge(left=df, right=df2, how='inner', on='Iata')
df_summary4.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5366 entries, ABE->ATL to YUM->SLC
# Data columns (total 5 columns):
# Total          5366 non-null int64
# Delayed        5366 non-null int64
# Cancelled      5366 non-null int64
# Problematic    5366 non-null int64
# PathName       5366 non-null object
# dtypes: int64(4), object(1)
# memory usage: 251.5+ KB

# %%
df_summary4.to_csv('data/FlighPaths2008_summary.csv', index=False)

# %%
#df_agg = pd.merge(left=df_summary4, right=df_out[['City','PathName']], how='inner', on='PathName')
#df_agg.drop_duplicates(inplace=True)
#df_agg.info(null_counts=True)

# %%
#df_agg.head(10)
